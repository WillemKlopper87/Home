# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Jako

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarised. This is an interesting field that is exponentially growing.

# %% [markdown]
# **Objectives:**
#
# - Understand the basics of Python and its relevance in Data Science
# - Identify key tools and environments used in Data Science workflows
# - Describe common libraries and packages in the Data Science ecosystem
# - Gain an overview of various data science tasks such as data analysis, visualization, and machine learning

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Dask

# %% [markdown]
# |Data Science Tools |
# |------|
# |Python |
# |R Studio |
# |VSCode |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#  This a simple arithmetic expression to mutiply then add integers
temp = (3*4)+5
print(temp)
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = (minutes/60)
print("200 minutes translates to" ,hours,"hours.")
# Out:
# 200 minutes translates to 3.3333333333333335 hours.
